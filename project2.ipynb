# %% [markdown]
# ## Building E2E Data engineering project with PySpark
#
# - In this project we will be going through an example that will help the company categorize their data based on the thumb nail
# - What are the factors that mesure how popular our youtube video will be
#
#
# In this project we will:
#
# 1. Learn how to build a database from scratch using AWS S3
# 2. Understand the diffrence betwee a data lake and data where house
# 3. How to design a datalake and properly partition diffrent tables
# 4. How to build an AWS data catalouge
# 5. How to build an ETL pipline with glue Spark jobs
# 6. Using SQL with Amazon athena and spark SQL
# 7. Write scripts to injest data incremently with a schema evelution
# 8. Finally build a Dashboard for viewing the data
